# %%
print("Jaskaran singh")
print("Jaskaran singh")
print("Jaskaran singh")

# %%
print(2+3)
print("Jaskaran" + " " + "Singh")

for x in range(1,10):
      print(x)
      j=1
while j < 10 :
 print(j)
 j +=1

# %%
print('range(10,21):',list(range(10,21)))
a=int(input('enter number'))
for i in range(1,11):
    print(a,'x',i,'=',a*i)
for i in range(1,11):
    print('7 x ',i,'=',7*i)
print('\n')
for i in range(1,11):
    print('8 x ',i,'=',8*i)
print('\n')
for i in range(1,11):
    print('9 x ',i,'=',9*i)

# %%
n=int(input('sum till n:'))
sum=0
for i in range(1,n+1):
  sum=sum+n*i
print(sum)
